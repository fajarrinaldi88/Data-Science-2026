# %% [markdown]
# <a href="https://colab.research.google.com/github/fajarrinaldi88/Data-Science-2026/blob/main/Pertemuan1_FajarRinaldi_250401020204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   Nama : Fajar Rinaldi
# *   NIM  : 250401020204
# *   Kelas : IF405

# %%
# SEL 1: Output sederhana
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
# SEL 2: Variabel & tipe data
nama     = "Fajar Rinaldi"
angkatan = 2025
print(f"Halo, {nama} angkatan {angkatan}!")
# Out:
# Halo, Fajar Rinaldi angkatan 2025!

# %%
# SEL 3: List & perulangan
tools = ["Python","Colab","Jupyter","GitHub"]
for i, tool in enumerate(tools, 1):
  print(f"  {i}. {tool}")
# Out:
#   1. Python
#   2. Colab
#   3. Jupyter
#   4. GitHub

# %%
# SEL 4: Fungsi Python
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"
print(perkenalan("Fajar"," PJJ Informatika",2025))
# Out:
# Fajar |  PJJ Informatika | 2025

# %% [markdown]
# ### Apa yang Dipelajari:
# *   **Dasar-dasar Python:** Mengenal sintaks dasar Python seperti mencetak output, mendeklarasikan variabel dan tipe data (string, integer), menggunakan list, melakukan perulangan (`for`), dan mendefinisikan serta memanggil fungsi.
# *   **Konsep Data Science:** Mendapatkan pengenalan awal tentang Data Science sebagai bidang yang mengintegrasikan Statistika, Ilmu Komputer, dan Domain Knowledge.
#
# ### Temuan Utama:
# *   Notebook ini berhasil mendemonstrasikan fundamental pemrograman Python yang menjadi dasar penting dalam pengembangan solusi Data Science.
#
# ### Keterbatasan atau Pertanyaan yang Muncul:
# *   Pembelajaran saat ini masih bersifat sangat dasar dan belum mencakup aplikasi Data Science yang lebih kompleks seperti analisis data, visualisasi, machine learning, atau penanganan data dari sumber eksternal.
